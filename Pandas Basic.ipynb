# %%
import numpy as np #importing NumPy
import pandas as pd #importing Pandas

# %%
myList = ["a","b","c"]
myList
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# ### Series

# %%
#Converting data to Series 
ser = pd.Series(myList)
ser
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
inx = ["I","II","III"]
ser = pd.Series(myList,inx)
ser
# Out:
# I      a
# II     b
# III    c
# dtype: object

# %%
tupl = ("a","b","c")

# %%
ser = pd.Series(tupl,['Earth','Mars','Jupiter'])
ser
# Out:
# Earth      a
# Mars       b
# Jupiter    c
# dtype: object

# %%
my_list = [1,2,3]
my_list * 2
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
#Series Computation
ser = pd.Series(my_list)
ser * 2
# Out:
# 0    2
# 1    4
# 2    6
# dtype: int64

# %%
pd.Series([10,9],["Maths","Science"])
# Out:
# Maths      10
# Science     9
# dtype: int64

# %%
pd.Series([10,9])
# Out:
# 0    10
# 1     9
# dtype: int64

# %%
#Addition on Series
m1 = pd.Series([10,9],["Maths","Science"])
m2 = pd.Series([8,10],["Science","Maths"])
m1 + m2
# Out:
# Maths      20
# Science    17
# dtype: int64

# %%
m1 = pd.Series([10,9],["Maths","Science"])
m2 = pd.Series([8,10],["Geo","Maths"])
m1 + m2
# Out:
# Geo         NaN
# Maths      20.0
# Science     NaN
# dtype: float64

# %%
m1 = pd.Series([10,9],["Maths","Science"])
m2 = pd.Series([8,10],["Geo","Maths"])
m3 = pd.Series([7,9],["Science","Maths"])
m1 * m2 * m3
# Out:
# Geo          NaN
# Maths      900.0
# Science      NaN
# dtype: float64

# %% [markdown]
# ## DataFrame

# %%
emp_df = {"emp_name":["Sam","Mike","Frodo","Gibs"],"salary":[20000,25000,30000,28000]}
print(emp_df)
type(emp_df)
# Out:
# {'emp_name': ['Sam', 'Mike', 'Frodo', 'Gibs'], 'salary': [20000, 25000, 30000, 28000]}
# dict

# %%
df = pd.DataFrame(emp_df)
df
# Out:
#   emp_name  salary
# 0      Sam   20000
# 1     Mike   25000
# 2    Frodo   30000
# 3     Gibs   28000

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Changing the row index

# %%
df = pd.DataFrame(emp_df,index=['a','b','c','d'])
df
# Out:
#   emp_name  salary
# a      Sam   20000
# b     Mike   25000
# c    Frodo   30000
# d     Gibs   28000

# %% [markdown]
# ### Accessing Column values

# %%
df['emp_name']
# Out:
# a      Sam
# b     Mike
# c    Frodo
# d     Gibs
# Name: emp_name, dtype: object

# %%
df.emp_name
# Out:
# a      Sam
# b     Mike
# c    Frodo
# d     Gibs
# Name: emp_name, dtype: object

# %%
#Converting to series to array
df['emp_name'].values
# Out:
# array(['Sam', 'Mike', 'Frodo', 'Gibs'], dtype=object)

# %%
df.emp_name.values
# Out:
# array(['Sam', 'Mike', 'Frodo', 'Gibs'], dtype=object)

# %% [markdown]
# ## Slicing

# %%
df
# Out:
#   emp_name  salary
# a      Sam   20000
# b     Mike   25000
# c    Frodo   30000
# d     Gibs   28000

# %%
df.shape
# Out:
# (4, 2)

# %%
#Slicing top values
df.head(2)
# Out:
#   emp_name  salary
# a      Sam   20000
# b     Mike   25000

# %%
#Slicing from bottom
df.tail(2)
# Out:
#   emp_name  salary
# c    Frodo   30000
# d     Gibs   28000

# %%
df.loc[['b','c']] #Getting middle values
# Out:
#   emp_name  salary
# b     Mike   25000
# c    Frodo   30000

# %%
df.iloc[1:3] #[i:j+1] integer based location
# Out:
#   emp_name  salary
# b     Mike   25000
# c    Frodo   30000

# %%
df_in = pd.DataFrame(emp_df)
df_in
# Out:
#   emp_name  salary
# 0      Sam   20000
# 1     Mike   25000
# 2    Frodo   30000
# 3     Gibs   28000

# %%
df_in.loc[1:2]
# Out:
#   emp_name  salary
# 1     Mike   25000
# 2    Frodo   30000

# %% [markdown]
# ## Merging

# %%
emp_df1 = pd.DataFrame({"emp_name":["Sam","Mike","Frodo","Gibs"],"salary":[20000,25000,30000,28000]})
emp_df2 = pd.DataFrame({"emp_name":["Sam","Mike","Frodo","Gibs"],"salary":[21000,25000,30000,28000]})
merg = pd.merge(emp_df1,emp_df2)
merg
# Out:
#   emp_name  salary
# 0     Mike   25000
# 1    Frodo   30000
# 2     Gibs   28000

# %%
merg = pd.merge(emp_df1,emp_df2,on="emp_name")
merg
# Out:
#   emp_name  salary_x  salary_y
# 0      Sam     20000     21000
# 1     Mike     25000     25000
# 2    Frodo     30000     30000
# 3     Gibs     28000     28000

# %% [markdown]
# ## Joining

# %%
df1 = pd.DataFrame({"emp_name":["Sam","Mike","Frodo","Gibs"],"salary":[20000,25000,30000,28000]},index=[1,2,3,4])
df2 = pd.DataFrame({"Leaves":[10,20,30,25]},index=[1,2,3,5])

# %%
df1
# Out:
#   emp_name  salary
# 1      Sam   20000
# 2     Mike   25000
# 3    Frodo   30000
# 4     Gibs   28000

# %%
df2
# Out:
#    Leaves
# 1      10
# 2      20
# 3      30
# 5      25

# %%
jn = df1.join(df2) #left join
jn
# Out:
#   emp_name  salary  Leaves
# 1      Sam   20000    10.0
# 2     Mike   25000    20.0
# 3    Frodo   30000    30.0
# 4     Gibs   28000     NaN

# %%
jn = df2.join(df1)
jn
# Out:
#    Leaves emp_name   salary
# 1      10      Sam  20000.0
# 2      20     Mike  25000.0
# 3      30    Frodo  30000.0
# 5      25      NaN      NaN

# %%
help(pd.DataFrame.join)
# Out:
# Help on function join in module pandas.core.frame:
#
# join(self, other, on=None, how='left', lsuffix='', rsuffix='', sort=False)
#     Join columns of another DataFrame.
#
#     Join columns with `other` DataFrame either on index or on a key
#     column. Efficiently join multiple DataFrame objects by index at once by
#     passing a list.
#
#     Parameters
#     ----------
#     other : DataFrame, Series, or list of DataFrame
#         Index should be similar to one of the columns in this one. If a
#         Series is passed, its name attribute must be set, and that will be
#         used as the column name in the resulting joined DataFrame.
#     on : str, list of str, or array-like, optional
#         Column or index level name(s) in the caller to join on the index
#         in `other`, otherwise joins index-on-index. If multiple
#         values given, the `other` DataFrame must have a MultiIndex. Can
#         pass an array as the join key if it is not already contained in
# ...

# %% [markdown]
# ### Changing of Index - Column to row index

# %%
df = pd.DataFrame({"emp":["Sam","Mike","Frodo","Gibs"],"salary":[2000,25000,30000,28000],'Leaves':[10,22,34,53]})

# %%
df.head()
# Out:
#      emp  salary  Leaves
# 0    Sam    2000      10
# 1   Mike   25000      22
# 2  Frodo   30000      34
# 3   Gibs   28000      53

# %%
updIndex=df.set_index("emp")
updIndex
# Out:
#        salary  Leaves
# emp
# Sam      2000      10
# Mike    25000      22
# Frodo   30000      34
# Gibs    28000      53

# %%
df.index = df["emp"]
df.head()
# Out:
#          emp  salary  Leaves
# emp
# Sam      Sam    2000      10
# Mike    Mike   25000      22
# Frodo  Frodo   30000      34
# Gibs    Gibs   28000      53

# %%
#Change the df index directly
df.set_index("emp", inplace = True)

# %%
df
# Out:
#          emp  salary  Leaves
# emp
# Sam      Sam    2000      10
# Mike    Mike   25000      22
# Frodo  Frodo   30000      34
# Gibs    Gibs   28000      53

# %% [markdown]
# ### Concatenation

# %%
df1 = pd.DataFrame({"emp":["Sam","Mike","Frodo","Gibs"],"salary":[2000,25000,30000,28000]})

# %%
df1
# Out:
#      emp  salary
# 0    Sam    2000
# 1   Mike   25000
# 2  Frodo   30000
# 3   Gibs   28000

# %%
df2 = pd.DataFrame({"emp":["Mary","Leo","Dan","David"],"salary":[2000,25000,30000,28000]})

# %%
df2
# Out:
#      emp  salary
# 0   Mary    2000
# 1    Leo   25000
# 2    Dan   30000
# 3  David   28000

# %%
#Adding new rows
conc = pd.concat((df1,df2))

# %%
conc
# Out:
#      emp  salary
# 0    Sam    2000
# 1   Mike   25000
# 2  Frodo   30000
# 3   Gibs   28000
# 0   Mary    2000
# 1    Leo   25000
# 2    Dan   30000
# 3  David   28000

# %%
df = pd.DataFrame(emp_df)
df
# Out:
#   emp_name  salary
# 0      Sam   20000
# 1     Mike   25000
# 2    Frodo   30000
# 3     Gibs   28000

# %%
new_col = pd.DataFrame({'Address':['a','b','c','d']}) 
new_col.head()
# Out:
#   Address
# 0       a
# 1       b
# 2       c
# 3       d

# %%
#Adding new column
conc = pd.concat((df,new_col),axis = 1)
conc
# Out:
#   emp_name  salary Address
# 0      Sam   20000       a
# 1     Mike   25000       b
# 2    Frodo   30000       c
# 3     Gibs   28000       d

# %% [markdown]
# ### Pandas IO

# %%
data=pd.read_csv('datasets/googleplaystore.csv')

# %%
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
data.shape
# Out:
# (10841, 13)

# %%
#Converting data frame to html
data.to_html('newData.html') #data wrangling/data munging

# %%
#Debugging error - incase the above code to_html() throws error
html = data.to_html()
with open("newData.html", "w", encoding="utf-8") as file:
    file.write(html)

# %%
#Converting data frame to json
data.to_json('data.json')

# %%
#Converting data frame to dictionary
data.to_dict()
# Out:
# {'`App': {0: 'Photo Editor & Candy Camera & Grid & ScrapBook',
#   1: 'Coloring book moana',
#   2: 'U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#   3: 'Sketch - Draw & Paint',
#   4: 'Pixel Draw - Number Art Coloring Book',
#   5: 'Paper flowers instructions',
#   6: 'Smoke Effect Photo Maker - Smoke Editor',
#   7: 'Infinite Painter',
#   8: 'Garden Coloring Book',
#   9: 'Kids Paint Free - Drawing Fun',
#   10: 'Text on Photo - Fonteee',
#   11: 'Name Art Photo Editor - Focus n Filters',
#   12: 'Tattoo Name On My Photo Editor',
#   13: 'Mandala Coloring Book',
#   14: '3D Color Pixel by Number - Sandbox Art Coloring',
#   15: 'Learn To Draw Kawaii Characters',
#   16: 'Photo Designer - Write your name with shapes',
#   17: '350 Diy Room Decor Ideas',
#   18: 'FlipaClip - Cartoon animation',
#   19: 'ibis Paint X',
#   20: 'Logo Maker - Small Business',
#   21: "Boys Photo Editor - Six Pack & Men's Suit",
#   22: 'Superheroes Wallpapers | 4K Backgrounds',
# ...

# %%
#Reading excel sheets
dataset=pd.read_excel('/Users/swaruptripathy/Desktop/Data Science and AI/datasets/AmazingMartEU2.xlsx','ListOfOrders')

# %%
dataset.shape
# Out:
# (4117, 10)

# %%
dataset.head()
# Out:
#           Order ID Order Date     Customer Name        City         Country  \
# 0  BN-2011-7407039 2011-01-01        Ruby Patel   Stockholm          Sweden
# 1  AZ-2011-9050313 2011-01-03    Summer Hayward   Southport  United Kingdom
# 2  AZ-2011-6674300 2011-01-04  Devin Huddleston     Valence          France
# 3  BN-2011-2819714 2011-01-04       Mary Parker  Birmingham  United Kingdom
# 4   AZ-2011-617423 2011-01-05      Daniel Burke  Echirolles          France
#
#     Region      Segment  Ship Date     Ship Mode                 State
# 0    North  Home Office 2011-01-05  Economy Plus             Stockholm
# 1    North     Consumer 2011-01-07       Economy               England
# 2  Central     Consumer 2011-01-08       Economy  Auvergne-Rhône-Alpes
# 3    North    Corporate 2011-01-09       Economy               England
# 4  Central  Home Office 2011-01-07      Priority  Auvergne-Rhône-Alpes

# %%
df1 = pd.read_excel('/Users/swaruptripathy/Desktop/Data Science and AI/datasets/AmazingMartEU2.xlsx','ListOfOrders')
df2 = pd.read_excel('/Users/swaruptripathy/Desktop/Data Science and AI/datasets/AmazingMartEU2.xlsx','OrderBreakdown')

# %%
df1.head()
# Out:
#           Order ID Order Date     Customer Name        City         Country  \
# 0  BN-2011-7407039 2011-01-01        Ruby Patel   Stockholm          Sweden
# 1  AZ-2011-9050313 2011-01-03    Summer Hayward   Southport  United Kingdom
# 2  AZ-2011-6674300 2011-01-04  Devin Huddleston     Valence          France
# 3  BN-2011-2819714 2011-01-04       Mary Parker  Birmingham  United Kingdom
# 4   AZ-2011-617423 2011-01-05      Daniel Burke  Echirolles          France
#
#     Region      Segment  Ship Date     Ship Mode                 State
# 0    North  Home Office 2011-01-05  Economy Plus             Stockholm
# 1    North     Consumer 2011-01-07       Economy               England
# 2  Central     Consumer 2011-01-08       Economy  Auvergne-Rhône-Alpes
# 3    North    Corporate 2011-01-09       Economy               England
# 4  Central  Home Office 2011-01-07      Priority  Auvergne-Rhône-Alpes

# %%
df2.head()
# Out:
#           Order ID                           Product Name  Discount  Sales  \
# 0  BN-2011-7407039            Enermax Note Cards, Premium       0.5     45
# 1  AZ-2011-9050313     Dania Corner Shelving, Traditional       0.0    854
# 2  AZ-2011-6674300  Binney & Smith Sketch Pad, Easy-Erase       0.0    140
# 3  BN-2011-2819714             Boston Markers, Easy-Erase       0.5     27
# 4  BN-2011-2819714            Eldon Folders, Single Width       0.5     17
#
#    Profit  Quantity         Category Sub-Category
# 0     -26         3  Office Supplies        Paper
# 1     290         7        Furniture    Bookcases
# 2      21         3  Office Supplies          Art
# 3     -22         2  Office Supplies          Art
# 4      -1         2  Office Supplies      Storage

# %% [markdown]
# ## Using merge

# %%
pd.merge(left=df1,right=df2, left_on='Order ID', right_on='Order ID')
# Out:
#              Order ID Order Date        Customer Name              City  \
# 0     BN-2011-7407039 2011-01-01           Ruby Patel         Stockholm
# 1     AZ-2011-9050313 2011-01-03       Summer Hayward         Southport
# 2     AZ-2011-6674300 2011-01-04     Devin Huddleston           Valence
# 3     BN-2011-2819714 2011-01-04          Mary Parker        Birmingham
# 4     BN-2011-2819714 2011-01-04          Mary Parker        Birmingham
# 5      AZ-2011-617423 2011-01-05         Daniel Burke        Echirolles
# 6      AZ-2011-617423 2011-01-05         Daniel Burke        Echirolles
# 7     AZ-2011-2918397 2011-01-07   Fredrick Beveridge  La Seyne-sur-Mer
# 8     AZ-2011-2918397 2011-01-07   Fredrick Beveridge  La Seyne-sur-Mer
# 9     AZ-2011-2918397 2011-01-07   Fredrick Beveridge  La Seyne-sur-Mer
# 10    BN-2011-3248724 2011-01-08          Archer Hort          Toulouse
# 11    BN-2011-3248724 2011-01-08          Archer Hort          Toulouse
# ...

# %%
#Reading .data format files
data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',names=['Sepal length','Sepal width','Petal length','Petal width','Class'])

# %%
data.head()
# Out:
#    Sepal length  Sepal width  Petal length  Petal width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
data.shape
# Out:
# (150, 5)
